# %%
import pandas as pd
import os

# %%
PATH = os.getcwd()

# %%
df = pd.read_csv("D:/Project/all_2022/dacon/ImForSicksHeaven/data/data_merged.csv")

# %%
df.tail()
# Out:
#       Unnamed: 0    GW     GW.1    GW.2    GW.3    GW.4    GW.5  GW.6 GW.7  \
# 1457  2021-12-27  23.0  373.361  339996  167949  164058  332162  6819   43
# 1458  2021-12-28  42.0   372.84  339996  167949  164058  347442  6870   51
# 1459  2021-12-29  54.0  372.609  339996  167949  164058  359176  6919   49
# 1460  2021-12-30  26.0  375.444  339996  167949  164058  377097  6981   62
# 1461  2021-12-31  21.0  373.701  339996  167949  164058  347905  7042   61
#
#          GW.8  ...  total.6 total.7 total.8 total.9 total.10 total.11  \
# 1457  164.958  ...  1.06414    -7.6   -12.9    -3.9      0.0     60.9
# 1458  164.958  ...  2.64255    -4.1    -8.5    -0.9      0.0     73.8
# 1459  164.958  ...  3.88771     0.4    -3.8     5.9      0.2     72.9
# 1460  164.958  ...  1.68006    -3.9    -6.8     0.2      0.0     48.5
# 1461  164.958  ...  0.90921    -6.7    -8.8    -3.9      0.0     35.9
#
#      total.12 total.13 total.14 total.15
# 1457      0.0      0.0      0.0      0.0
# ...

# %%
# Out:
# 'd:\\Project\\all_2022\\dacon\\ImForSicksHeaven\\data'
